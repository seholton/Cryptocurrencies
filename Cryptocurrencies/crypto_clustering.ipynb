# %%
# Initial imports
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ## Deliverable 1

# %%
# Load the crypto_data.csv dataset.
# YOUR CODE HERE
file_path = "Resources/crypto_data.csv"
crypto_df = pd.read_csv(file_path, index_col=0)
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (1252, 6)
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337    314159265359
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %%
# Keep all the cryptocurrencies that are being traded.
# YOUR CODE HERE
crypto_df = crypto_df[crypto_df['IsTrading'] == True] 
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (1144, 6)
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337    314159265359
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %%
# Remove the "IsTrading" column. 
# YOUR CODE HERE
crypto_df = crypto_df.drop(columns="IsTrading")
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (1144, 5)
#        CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 365     365Coin       X11   PoW/PoS              NaN      2300000000
# 404     404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 611   SixEleven   SHA-256       PoW              NaN          611000
# 808         808   SHA-256   PoW/PoS     0.000000e+00               0
# 1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# 2015  2015 coin       X11   PoW/PoS              NaN               0
# BTC     Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# ETH    Ethereum    Ethash       PoW     1.076842e+08               0
# LTC    Litecoin    Scrypt       PoW     6.303924e+07        84000000

# %%
# Remove rows that have at least 1 null value.
# YOUR CODE HERE
crypto_df = crypto_df[~(crypto_df.isna() == True).any(axis=1)]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (685, 5)
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 808                808         SHA-256   PoW/PoS     0.000000e+00
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 808                0
# 1337    314159265359
# BTC         21000000
# ETH                0
# LTC         84000000
# DASH        22000000
# XMR                0
# ETC        210000000

# %%
# Keep all the cryptocurrencies that have a working algorithm.
# YOUR CODE HERE
crypto_df = crypto_df[crypto_df.Algorithm.isna() == False]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (685, 5)
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 808                808         SHA-256   PoW/PoS     0.000000e+00
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 808                0
# 1337    314159265359
# BTC         21000000
# ETH                0
# LTC         84000000
# DASH        22000000
# XMR                0
# ETC        210000000

# %%
# Keep the rows where coins are mined.
# YOUR CODE HERE
crypto_df = crypto_df[~(crypto_df.TotalCoinsMined <= 0)]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (532, 5)
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
# ZEC              ZCash        Equihash       PoW     7.383056e+06
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 1337    314159265359
# BTC         21000000
# ETH                0
# LTC         84000000
# DASH        22000000
# XMR                0
# ETC        210000000
# ZEC         21000000

# %%
# Create a new DataFrame that holds only the cryptocurrencies names.
# YOUR CODE HERE
crypto_name_df = pd.DataFrame(crypto_df.CoinName)
print(crypto_name_df.shape)
crypto_name_df.head()
# Out:
# (532, 1)
#        CoinName
# 42      42 Coin
# 404     404Coin
# 1337  EliteCoin
# BTC     Bitcoin
# ETH    Ethereum

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm.
# YOUR CODE HERE
crypto_df = crypto_df.drop(columns="CoinName")
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (532, 4)
#            Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42            Scrypt   PoW/PoS     4.199995e+01              42
# 404           Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337             X13   PoW/PoS     2.927942e+10    314159265359
# BTC          SHA-256       PoW     1.792718e+07        21000000
# ETH           Ethash       PoW     1.076842e+08               0
# LTC           Scrypt       PoW     6.303924e+07        84000000
# DASH             X11   PoW/PoS     9.031294e+06        22000000
# XMR   CryptoNight-V7       PoW     1.720114e+07               0
# ETC           Ethash       PoW     1.133597e+08       210000000
# ZEC         Equihash       PoW     7.383056e+06        21000000

# %%
# Use get_dummies() to create variables for text features.
# YOUR CODE HERE
X = pd.get_dummies(crypto_df, columns=["Algorithm", "ProofType"])
print(X.shape)
X.head(10)
# Out:
# (532, 98)
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10    314159265359                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
# LTC      6.303924e+07        84000000                                 0
# DASH     9.031294e+06        22000000                                 0
# XMR      1.720114e+07               0                                 0
# ETC      1.133597e+08       210000000                                 0
# ZEC      7.383056e+06        21000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 42                0                  0                   0                0
# 404               0                  0                   0                0
# 1337              0                  0                   0                0
# BTC               0                  0                   0                0
# ETH               0                  0                   0                0
# LTC               0                  0                   0                0
# DASH              0                  0                   0                0
# XMR               0                  0                   0                0
# ETC               0                  0                   0                0
# ZEC               0                  0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# 42                    0                  0              0  ...
# 404                   0                  0              0  ...
# 1337                  0                  0              0  ...
# BTC                   0                  0              0  ...
# ETH                   0                  0              0  ...
# LTC                   0                  0              0  ...
# DASH                  0                  0              0  ...
# XMR                   0                  0              0  ...
# ETC                   0                  0              0  ...
# ZEC                   0                  0              0  ...
#
#       ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 42                    1                   0                  0
# 404                   1                   0                  0
# 1337                  1                   0                  0
# BTC                   0                   0                  0
# ETH                   0                   0                  0
# LTC                   0                   0                  0
# DASH                  1                   0                  0
# XMR                   0                   0                  0
# ETC                   0                   0                  0
# ZEC                   0                   0                  0
#
#       ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 42                     0              0                             0
# 404                    0              0                             0
# 1337                   0              0                             0
# BTC                    0              0                             0
# ETH                    0              0                             0
# LTC                    0              0                             0
# DASH                   0              0                             0
# XMR                    0              0                             0
# ETC                    0              0                             0
# ZEC                    0              0                             0
#
#       ProofType_Proof of Trust  ProofType_TPoS  \
# 42                           0               0
# 404                          0               0
# 1337                         0               0
# BTC                          0               0
# ETH                          0               0
# LTC                          0               0
# DASH                         0               0
# XMR                          0               0
# ETC                          0               0
# ZEC                          0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# 42                                 0                   0
# 404                                0                   0
# 1337                               0                   0
# BTC                                0                   0
# ETH                                0                   0
# LTC                                0                   0
# DASH                               0                   0
# XMR                                0                   0
# ETC                                0                   0
# ZEC                                0                   0
#
# [10 rows x 98 columns]

# %% [markdown]
# ## Deliverable 2

# %%
# Using PCA to reduce dimension to three principal components.
# YOUR CODE HERE
pca = PCA(n_components=3)

crypto_pca = pca.fit_transform(crypto_scaled)

crypto_pca
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4r/w_7j51g52k19k0g5w66z3ltr0000gn/T/ipykernel_96496/3925881432.py in <module>
#       2 # YOUR CODE HERE
#       3 pca = PCA(n_components=3)
# ----> 4 crypto_pca = pca.fit_transform(crypto_scaled)
#       5 crypto_pca
#
# NameError: name 'crypto_scaled' is not defined

# %%
# Create a DataFrame with the three principal components.

pcs_df = pd.DataFrame(crypto_pca, columns=["PC 1", "PC 2", "PC 3"], index=crypto_name_df.index)
print(pcs_df.shape)
pcs_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4r/w_7j51g52k19k0g5w66z3ltr0000gn/T/ipykernel_96496/1699741146.py in <module>
#       1 # Create a DataFrame with the three principal components.
#       2 # YOUR CODE HERE
# ----> 3 pcs_df = pd.DataFrame(crypto_pca, columns=["PC 1", "PC 2", "PC 3"], index=crypto_name_df.index)
#       4 print(pcs_df.shape)
#       5 pcs_df.head(10)
#
# NameError: name 'crypto_pca' is not defined

# %% [markdown]
# ## Deliverable 3

# %%
# Create an elbow curve to find the best value for K.
# YOUR CODE HERE
# Initialize empty inertia list
inertia = []
# Initialize k range
k = list(range(1,11))
# Looping through k list
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Define a DataFrame to plot the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
elbow_df = pd.DataFrame(elbow_data)
elbow_df.hvplot.line(x="k", y="inertia", title="Elbow Curve", xticks=k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4r/w_7j51g52k19k0g5w66z3ltr0000gn/T/ipykernel_96496/3836004439.py in <module>
#       8 for i in k:
#       9     km = KMeans(n_clusters=i, random_state=0)
# ---> 10     km.fit(pcs_df)
#      11     inertia.append(km.inertia_)
#      12
#
# NameError: name 'pcs_df' is not defined

# %%
# Initialize the K-Means model.
# YOUR CODE HERE
km_model = KMeans(n_clusters=4, random_state=0)
# Fit the model
# YOUR CODE HERE
km_model.fit(pcs_df)
# Predict clusters
# YOUR CODE HERE
predictions = km_model.predict(pcs_df)
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4r/w_7j51g52k19k0g5w66z3ltr0000gn/T/ipykernel_96496/1428496545.py in <module>
#       4 # Fit the model
#       5 # YOUR CODE HERE
# ----> 6 km_model.fit(pcs_df)
#       7 # Predict clusters
#       8 # YOUR CODE HERE
#
# NameError: name 'pcs_df' is not defined

# %%
# Create a new DataFrame including predicted clusters and cryptocurrencies features.
# Concatentate the crypto_df and pcs_df DataFrames on the same columns.
# YOUR CODE HERE
clustered_df = pd.concat([crypto_df, pcs_df], axis=1, join='inner')
#  Add a new column, "CoinName" to the clustered_df DataFrame that holds the names of the cryptocurrencies. 

clustered_df["CoinName"] = crypto_name_df.CoinName
#  Add a new column, "Class" to the clustered_df DataFrame that holds the predictions.

clustered_df["Class"] = km_model.labels_
# Print the shape of the clustered_df
print(clustered_df.shape)
clustered_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4r/w_7j51g52k19k0g5w66z3ltr0000gn/T/ipykernel_96496/2168536802.py in <module>
#       2 # Concatentate the crypto_df and pcs_df DataFrames on the same columns.
#       3 # YOUR CODE HERE
# ----> 4 clustered_df = pd.concat([crypto_df, pcs_df], axis=1, join='inner')
#       5 #  Add a new column, "CoinName" to the clustered_df DataFrame that holds the names of the cryptocurrencies.
#       6 # YOUR CODE HERE
#
# NameError: name 'pcs_df' is not defined

# %% [markdown]
# ## Deliverable 4

# %%
# Creating a 3D-Scatter with the PCA data and the clusters

fig = px.scatter_3d(clustered_df, x="PC 1", y="PC 2", z="PC 3", color="Class", symbol="Class", width=800, 
                    hover_name="CoinName", hover_data=["Algorithm"])
fig.update_layout(legend=dict(x=0, y=1))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4r/w_7j51g52k19k0g5w66z3ltr0000gn/T/ipykernel_96496/2458483568.py in <module>
#       1 # Creating a 3D-Scatter with the PCA data and the clusters
#       2 # YOUR CODE HERE
# ----> 3 fig = px.scatter_3d(clustered_df, x="PC 1", y="PC 2", z="PC 3", color="Class", symbol="Class", width=800,
#       4                     hover_name="CoinName", hover_data=["Algorithm"])
#       5 fig.update_layout(legend=dict(x=0, y=1))
#
# NameError: name 'clustered_df' is not defined

# %%
# Create a table with tradable cryptocurrencies.
# YOUR CODE HERE
tradable_crypto_table = clustered_df.hvplot.table(columns=['CoinName', 'Algorithm', 'ProofType', 'TotalCoinSupply', 
                                                  'TotalCoinsMined', 'Class'], sortable=True, selectable=True)
tradable_crypto_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4r/w_7j51g52k19k0g5w66z3ltr0000gn/T/ipykernel_96496/1225667626.py in <module>
#       1 # Create a table with tradable cryptocurrencies.
#       2 # YOUR CODE HERE
# ----> 3 tradable_crypto_table = clustered_df.hvplot.table(columns=['CoinName', 'Algorithm', 'ProofType', 'TotalCoinSupply',
#       4                                                   'TotalCoinsMined', 'Class'], sortable=True, selectable=True)
#       5 tradable_crypto_table
#
# NameError: name 'clustered_df' is not defined

# %%
# Print the total number of tradable cryptocurrencies.
# YOUR CODE HERE
print(f'There are {len(clustered_df)} tradable cryptocurrencies.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4r/w_7j51g52k19k0g5w66z3ltr0000gn/T/ipykernel_96496/1607985319.py in <module>
#       1 # Print the total number of tradable cryptocurrencies.
#       2 # YOUR CODE HERE
# ----> 3 print(f'There are {len(clustered_df)} tradable cryptocurrencies.')
#
# NameError: name 'clustered_df' is not defined

# %%
# Scaling data to create the scatter plot with tradable cryptocurrencies.
# YOUR CODE HERE
X_cluster = clustered_df[['TotalCoinSupply', 'TotalCoinsMined']].copy()
X_cluster_scaled = MinMaxScaler().fit_transform(X_cluster)
X_cluster_scaled
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4r/w_7j51g52k19k0g5w66z3ltr0000gn/T/ipykernel_96496/2792630815.py in <module>
#       1 # Scaling data to create the scatter plot with tradable cryptocurrencies.
#       2 # YOUR CODE HERE
# ----> 3 X_cluster = clustered_df[['TotalCoinSupply', 'TotalCoinsMined']].copy()
#       4 X_cluster_scaled = MinMaxScaler().fit_transform(X_cluster)
#       5 X_cluster_scaled
#
# NameError: name 'clustered_df' is not defined

# %%
# Create a new DataFrame that has the scaled data with the clustered_df DataFrame index.
# YOUR CODE HERE
plot_df = pd.DataFrame(X_cluster_scaled, columns=['TotalCoinSupply', 'TotalCoinsMined'], index=clustered_df.index)
# Add the "CoinName" column from the clustered_df DataFrame to the new DataFrame.
# YOUR CODE HERE
plot_df['CoinName'] = clustered_df.CoinName
# Add the "Class" column from the clustered_df DataFrame to the new DataFrame. 
# YOUR CODE HERE
plot_df['Class'] = clustered_df.Class
plot_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4r/w_7j51g52k19k0g5w66z3ltr0000gn/T/ipykernel_96496/581123148.py in <module>
#       1 # Create a new DataFrame that has the scaled data with the clustered_df DataFrame index.
#       2 # YOUR CODE HERE
# ----> 3 plot_df = pd.DataFrame(X_cluster_scaled, columns=['TotalCoinSupply', 'TotalCoinsMined'], index=clustered_df.index)
#       4 # Add the "CoinName" column from the clustered_df DataFrame to the new DataFrame.
#       5 # YOUR CODE HERE
#
# NameError: name 'X_cluster_scaled' is not defined

# %%
# Create a hvplot.scatter plot using x="TotalCoinsMined" and y="TotalCoinSupply".
# YOUR CODE HERE
plot_df.hvplot.scatter(x='TotalCoinsMined', y='TotalCoinSupply', hover_cols='CoinName', by='Class')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4r/w_7j51g52k19k0g5w66z3ltr0000gn/T/ipykernel_96496/743911050.py in <module>
#       1 # Create a hvplot.scatter plot using x="TotalCoinsMined" and y="TotalCoinSupply".
#       2 # YOUR CODE HERE
# ----> 3 plot_df.hvplot.scatter(x='TotalCoinsMined', y='TotalCoinSupply', hover_cols='CoinName', by='Class')
#
# NameError: name 'plot_df' is not defined
